# %% [markdown]
# <a href="https://colab.research.google.com/github/samecabh/aulageneration/blob/main/Aula_Mercado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# O nosso desafio é mostrar os produtos de um mercado
# Quero poder escolhe os produtos, para ver infos
# Quero poder adicionar novos produtos
# Quero poder excluir um produto

# Criar as variáveis globais para o software
lista_produtos = ['Detergente Ype',
                  'Refrigerante Gengibirra',
                  'Arroz',
                  'Feijão',
                  'Água Mineral']

lista_preco = [2.50, 5, 7.25, 4, 3.45]

# %%
# Função 1 - Ver Produtos
def ver_produtos():
  print(f'Os produtos que temos são: {lista_produtos}')
  print(f'E seus preços são: {lista_preco}')

def adicionar_produtos():
  novo_produto = input('Informe o nome do produto: ')
  novo_preco = float(input('Informe o preço: '))
  lista_produtos.append(novo_produto)
  # /\ CHAMAMOS A LISTA - ATRIBUÍMOS A FUNÇÃO APPEND (ADICIONA) -
  # COLOCAMOS O QUE VAI SER ADICIONADO
  lista_preco.append(novo_preco)

# %%
print('-----MENU DO MERCADO-----')
print('Escolha a opção:')
print('1 - Ver produtos')
print('2 - Cadastrar novo produto')
opcao = int(input('Informe a opção desejada'))

if opcao == 1:
  ver_produtos()
elif opcao ==2:
  adicionar_produtos()
  ver_produtos()
else:
  print('Opção não encontrada')
# Out:
# -----MENU DO MERCADO-----
# Escolha a opção:
# 1 - Ver produtos
# 2 - Cadastrar novo produto
# Informe a opção desejada2
# Informe o nome do produto: Banana
# Informe o preço: 1.99
# Os produtos que temos são: ['Detergente Ype', 'Refrigerante Gengibirra', 'Arroz', 'Feijão', 'Água Mineral', 'Biscoito', 'Banana']
# E seus preços são: [2.5, 5, 7.25, 4, 3.45, 7.49, 1.99]
