# %% [markdown]
# <a href="https://colab.research.google.com/github/samecabh/aulageneration/blob/main/Aula_Variaveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = "Sâmec"
print(f"Olá {nome}")
# Out:
# Olá Sâmec

# %%
nome = "Sâmec"
idade = 23
cidade = "Hortolândia"

print(f"Olá {nome}, você tem {idade} anos, mora em {cidade}")
# Out:
# Olá Sâmec, você tem 23 anos, mora em Hortocity
